# %%
from math import nan
import pandas as pd
import json, os, re

data = []
root = "./raw_data/"
for file in os.listdir(root):
    data.append(json.load(open(root+file)))

data = pd.DataFrame(data)
for col in data.columns:
    data[col] = data[col].apply(lambda x: nan if type(x) != str and x == None else x )

data = data.dropna(subset="code")
data
# Out:
#                 code                                            sources  \
# 0      8710400200833  [https://www.ah.nl/producten/product/wi54074/a...
# 1      8718265184886  [https://www.ah.nl/producten/product/wi197393/...
# 2      8710400261803  [https://www.ah.nl/producten/product/wi94782/a...
# 3      8718265948518  [https://www.ah.nl/producten/product/wi4117/ah...
# 4      8722800072026  [https://www.ah.nl/producten/product/wi4164/ah...
# ...              ...                                                ...
# 11534  8718907384797  [https://www.ah.nl/producten/product/wi482197/...
# 11535  8718907384810  [https://www.ah.nl/producten/product/wi482199/...
# 11536  5411188133094  [https://www.ah.nl/producten/product/wi486434/...
# 11537  8710559037564  [https://www.ah.nl/producten/product/wi486809/...
# 11538  8718907360296  [https://www.ah.nl/producten/product/wi494116/...
#
#                                                image_url  \
# 0      https://static.ah.nl/static/product/AHI_434d50...
# 1      https://static.ah.nl/static/product/AHI_435452...
# 2      https://static.ah.nl/static/product/AHI_435452...
# 3      https://static.ah.nl/static/product/AHI_434d50...
# 4      https://static.ah.nl/static/product/AHI_434d50...
# ...                                                  ...
# 11534  https://static.ah.nl/static/product/AHI_435452...
# 11535  https://static.ah.nl/static/product/AHI_435452...
# 11536  https://static.ah.nl/static/product/AHI_435452...
# 11537  https://static.ah.nl/static/product/AHI_435452...
# 11538  https://static.ah.nl/static/product/AHI_435452...
#
#                                          small_image_url  \
# 0      https://static.ah.nl/static/product/AHI_434d50...
# 1      https://static.ah.nl/static/product/AHI_435452...
# 2      https://static.ah.nl/static/product/AHI_435452...
# 3      https://static.ah.nl/static/product/AHI_434d50...
# 4      https://static.ah.nl/static/product/AHI_434d50...
# ...                                                  ...
# 11534  https://static.ah.nl/static/product/AHI_435452...
# 11535  https://static.ah.nl/static/product/AHI_435452...
# 11536  https://static.ah.nl/static/product/AHI_435452...
# 11537  https://static.ah.nl/static/product/AHI_435452...
# 11538  https://static.ah.nl/static/product/AHI_435452...
#
#                                        product_name          brand nutriscore  \
# 0                                      AH Komkommer             AH          A
# 1                                        AH Bananen             AH          A
# 2                                    AH Mandarijnen             AH          A
# 3                                   AH Rode paprika             AH          A
# 4                                      AH Courgette             AH          A
# ...                                             ...            ...        ...
# 11534                            AH Sportdrank blue             AH          D
# 11535                          AH Sportdrank orange             AH          E
# 11536                   Alpro Barista haver gekoeld          Alpro          A
# 11537  Wilhelmina Extra frisse pepermunt suikervrij     Wilhelmina        NaN
# 11538                AH Glutenvrij Belgische wafels  AH Glutenvrij          D
#
#                                               categories  \
# 0      [Aardappel, groente, fruit, Groente, Komkommer...
# 1            [Aardappel, groente, fruit, Fruit, Bananen]
# 2      [Aardappel, groente, fruit, Fruit, Sinaasappel...
# 3      [Aardappel, groente, fruit, Groente, Tomaat, p...
# 4      [Aardappel, groente, fruit, Groente, Aubergine...
# ...                                                  ...
# 11534  [Frisdrank, sappen, koffie, thee, Energy drink...
# 11535  [Frisdrank, sappen, koffie, thee, Energy drink...
# 11536  [Bewuste voeding, Plantaardige drinks, Haverdr...
# 11537  [Snoep, koek, chips en chocolade, Snoep, Snoep...
# 11538  [Snoep, koek, chips en chocolade, Koek, Gluten...
#
#                                         ingredients_text  \
# 0                                                    NaN
# 1      banaanWaarvan toegevoegde suikers 0.00g per 10...
# 2      Waarvan toegevoegde suikers 0.00g per 100 gram...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11534  water, suiker, voedingszuur (citroenzuur [E330...
# 11535  water, suiker, dextrose, fructose, maltodextri...
# 11536  HAVERBASIS (water, HAVER (9,5%)), zonnebloemol...
# 11537  Zoetstoffen* (sorbitolen, xylitol, aspartaam**...
# 11538  rietsuiker, vrije-uitloopei, zonnebloemolie, z...
#
#                      calories
# 0                         NaN
# 1            91 kcal/100 gram
# 2            45 kcal/100 gram
# 3                         NaN
# 4                         NaN
# ...                       ...
# 11534  20 kcal/100 milliliter
# 11535  60 kcal/100 milliliter
# 11536  58 kcal/100 milliliter
# 11537       241 kcal/100 gram
# 11538       428 kcal/100 gram
#
# [11313 rows x 10 columns]

# %%
product_data = []
for i in data.index:
    product = data.loc[i].to_dict()
    for k,v in product.items():
        if type(v) == float:
            product[k] = None
    product_data.append(product)
json.dump(product_data,open("./data/product_data.json","w"))
print("done")
# Out:
# done
